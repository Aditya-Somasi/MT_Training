# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data_index=pd.read_csv("economic_index.csv")

# %%
data_index.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %%
#drop unneccessary columns
data_index.drop(columns=["Unnamed: 0","year","month"],axis=1,inplace=True)

# %%
data_index.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
##check null values
data_index.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
## Lets do some viualization
import seaborn as sns
sns.pairplot(data_index)

# %%
data_index.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
## Visualiza the datapoints more closely
plt.scatter(data_index['interest_rate'],data_index['unemployment_rate'],color='r')
plt.xlabel("Interest rate")
plt.ylabel("unemployment rate")
# Out:
# Text(0, 0.5, 'unemployment rate')

# %%
##independent and dependent features
X=data_index.iloc[:,:-1]
y=data_index.iloc[:,-1]

# %%
X.head()
# Out:
#    interest_rate  unemployment_rate
# 0           2.75                5.3
# 1           2.50                5.3
# 2           2.50                5.3
# 3           2.50                5.3
# 4           2.50                5.4

# %%
y
# Out:
# 0     1464
# 1     1394
# 2     1357
# 3     1293
# 4     1256
# 5     1254
# 6     1234
# 7     1195
# 8     1159
# 9     1167
# 10    1130
# 11    1075
# 12    1047
# 13     965
# 14     943
# 15     958
# 16     971
# 17     949
# 18     884
# 19     866
# 20     876
# 21     822
# 22     704
# 23     719
# Name: index_price, dtype: int64

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
import seaborn as sns

# %%
sns.regplot(x=data_index['interest_rate'], y=data_index['index_price'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='index_price'>

# %%
sns.regplot(x=data_index['interest_rate'],y=data_index['unemployment_rate'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='unemployment_rate'>

# %%
sns.regplot(x=data_index['index_price'],y=data_index['unemployment_rate'])
# Out:
# <Axes: xlabel='index_price', ylabel='unemployment_rate'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.90115511,  0.37908503],
#        [ 1.31077107, -1.48187786],
#        [-0.90115511,  1.30956648],
#        [ 1.31077107, -0.55139641],
#        [ 1.31077107, -1.48187786],
#        [-0.16384638,  0.68924552],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -1.48187786],
#        [ 1.31077107, -1.17171738],
#        [-0.90115511,  1.30956648],
#        [-0.90115511,  0.999406  ],
#        [-0.90115511,  0.37908503],
#        [-0.90115511,  0.999406  ],
#        [ 0.57346234, -0.8615569 ],
#        [-0.16384638, -0.24123593],
#        [-0.90115511,  0.06892455],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -0.8615569 ]])

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## cross validation
from sklearn.model_selection import cross_val_score
validation_score=cross_val_score(regression,X_train,y_train,scoring='neg_mean_squared_error',
                                cv=3)

# %%
np.mean(validation_score)
# Out:
# np.float64(-5914.828180162386)

# %%
## prediction
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([1204.22770398,  821.65051903, 1406.51300368,  857.70889608,
#         994.90992298, 1168.16932693])

# %%
## Performance Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 5793.762887712569
# 59.935781523235484
# 76.11677139574805

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
#display adjusted R-squared
print(1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# 0.8278978091457145
# 0.7131630152428576

# %% [markdown]
# ## Assumptions

# %%
plt.scatter(y_test,y_pred)

# %%
residuals=y_test-y_pred ## errors
print(residuals)
# Out:
# 8     -45.227704
# 16    149.349481
# 0      57.486996
# 18     26.291104
# 11     80.090077
# 9      -1.169327
# Name: index_price, dtype: float64

# %%
## Plot this residuals
sns.displot(residuals,kind='kde')

# %%
## scatter plot with respect to prediction and residuals
plt.scatter(y_pred,residuals)

# %%
# %pip install statsmodels

## OLS Linear Regression
import statsmodels.api as sm
X_train_sm = sm.add_constant(X_train)  # Add a constant term
model = sm.OLS(y_train, X_train_sm).fit()
# Out:
# ...
#   Using cached statsmodels-0.14.5.tar.gz (20.5 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: still running...
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# ...
# Failed to build statsmodels
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for statsmodels (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1557 lines of output]
# ...

# %%
model.summary()
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            index_price   R-squared (uncentered):                   0.035
# Model:                            OLS   Adj. R-squared (uncentered):             -0.086
# Method:                 Least Squares   F-statistic:                             0.2880
# Date:                Mon, 01 Aug 2022   Prob (F-statistic):                       0.754
# Time:                        22:16:49   Log-Likelihood:                         -150.85
# No. Observations:                  18   AIC:                                      305.7
# data Residuals:                      16   BIC:                                      307.5
# ...

# %%
print(regression.coef_)
# Out:
# [  88.27275507 -116.25716066]
